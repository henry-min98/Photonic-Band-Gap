# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'diamond_epsilon_11.56.csv')

# %%
print(df)
# Out:
#      epsilon  radius  max(w)  min(w)  differences
# 0      11.56   0.000     0.0     0.0          0.0
# 1      11.56   0.001     0.0     0.0          0.0
# 2      11.56   0.002     0.0     0.0          0.0
# 3      11.56   0.003     0.0     0.0          0.0
# 4      11.56   0.004     0.0     0.0          0.0
# ..       ...     ...     ...     ...          ...
# 495    11.56   0.495     0.0     0.0          0.0
# 496    11.56   0.496     0.0     0.0          0.0
# 497    11.56   0.497     0.0     0.0          0.0
# 498    11.56   0.498     0.0     0.0          0.0
# 499    11.56   0.499     0.0     0.0          0.0
#
# [500 rows x 5 columns]

# %%
df["epsilon"]
# Out:
# 0      11.56
# 1      11.56
# 2      11.56
# 3      11.56
# 4      11.56
#        ...
# 495    11.56
# 496    11.56
# 497    11.56
# 498    11.56
# 499    11.56
# Name: epsilon, Length: 500, dtype: float64

# %%
plt.xlabel('Radius')
plt.ylabel('Frequencies')
plt.title("Epsilon="+str(df["epsilon"][2]))
plt.scatter(df["radius"], df["max(w)"], marker='.', color="blue")
plt.scatter(df["radius"], df["min(w)"], marker='.', color="red")
plt.show()

# %%
plt.xlabel('Radius')
plt.ylabel('Frequencies')
plt.title("Epsilon="+str(j))
plt.scatter(df.iloc[i][1], df.iloc[i][2], marker='.', color="blue")
plt.scatter(df.iloc[i][1], df.iloc[i][3], marker='.', color="red")
plt.show()

# %%
"""
for j in range(3,20):
    for i in range(0,len(df)):
        if df.iloc[i][0] == j:
            plt.xlabel('Radius')
            plt.ylabel('Frequencies')
            plt.title("Epsilon="+str(j))

            plt.scatter(df.iloc[i][1], df.iloc[i][2], marker='.', color="blue")
            plt.scatter(df.iloc[i][1], df.iloc[i][3], marker='.', color="red")
    plt.show()
"""
